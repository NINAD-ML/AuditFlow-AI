# %%
import os
import cv2
import matplotlib.pyplot as plt

# Path to your dataset (update this path to where you put SROIE data)
data_path = "//Users/ninad/AuditFlow-AI/AuditFlow-AI/data/0325updated.task2train(626p)"

# pick one sample file
sample_img = os.path.join(data_path, "X00016469612.jpg")
sample_txt = os.path.join(data_path, "X00016469612.txt")

# load image
img = cv2.imread(sample_img)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# show image
plt.figure(figsize=(8,8))
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# show annotation text
with open(sample_txt, "r", encoding="utf-8") as f:
    print("Annotation File Content:\n")
    print(f.read())
# Out:
# Annotation File Content:
#
# {
#     "company": "BOOK TA .K (TAMAN DAYA) SDN BHD",
#     "date": "25/12/2018",
#     "address": "NO.53 55,57 & 59, JALAN SAGU 18, TAMAN DAYA, 81100 JOHOR BAHRU, JOHOR.",
#     "total": "9.00"
# }
